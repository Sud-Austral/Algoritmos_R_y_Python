# %%
from geopy.geocoders import Nominatim
import pandas as pd

df = pd.read_excel(r'C:\Users\usuario\Desktop\eleamdirecciones.xlsx', header=None)

#df

#df.iloc[2,0]

#address=' RAMON CARNICER PONIENTE 3186, Arica,Chile'

#address = df.iloc[2,0]
#geolocator = Nominatim(user_agent="Your_Name")
#location = geolocator.geocode(address)
#print(location.address)
#print((location.latitude, location.longitude))
L  = []

i = 1
while i < 929:
    address = df.iloc[i,0]
    geolocator = Nominatim(user_agent="Your_Name")
    location = geolocator.geocode(address)
    if(geolocator != None and location != None):
  #     L.append(address)
        
        print(address)
        a = address
        
        print(location.address)
        la = location.address
        
        print((location.latitude, location.longitude))
        llll = str(location.latitude) + " " + str(location.longitude)
        
        print(i)
        L.append(a + " " + la + " " + llll + " " + str(i))
        
    i += 1
    
df = pd.DataFrame(L, columns=['string_values'])
print (df)
df.to_excel(r'C:\Users\usuario\Desktop\eleamdireccionesfinales.xlsx', index = False)
# Out:
#  Calle 18 DE SEPTIEMBRE 1979, Arica, Chile
# 18 de Septiembre, Ticnamar, Putre, Provincia de Parinacota, Región de Arica y Parinacota, Chile
# (-18.5814965, -69.4938804)
# 1
#  Calle GUILLERMO SANCHEZ 641, Arica, Chile
# Guillermo Sánchez, Población Nueva Esperanza, Bellavista, Arica, Provincia de Arica, Región de Arica y Parinacota, 10000, Chile
# (-18.4926608, -70.2826108)
# 2
#  Calle GERMAN RIESCO 2016, Arica, Chile
# German Riesco, Población Maipú Oriente, Chinchorro, Arica, Provincia de Arica, Región de Arica y Parinacota, 1001110, Chile
# (-18.4814702, -70.3016212)
# 3
#  Calle REÑACA 391, Arica, Chile
# Reñaca, Magisterio, Chinchorro, Arica, Provincia de Arica, Región de Arica y Parinacota, 1001110, Chile
# (-18.4888081, -70.3114008)
# 4
#  Calle RAMON CARNICER PONIENTE 3186, Arica, Chile
# Ramón Carnicer Poniente, Tierras Blancas, Chinchorro, Arica, Provincia de Arica, Región de Arica y Parinacota, 1020759, Chile
# (-18.4526965, -70.2985859)
# 5
# ...

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\usuario\Desktop\eleam.xlsx', header=None)

d = df.iloc[1,1]
#deleam = d.split(',')[1]
#print(deleam)
#deleam.to_excel(r'C:\Users\usuario\Desktop\eleamdirecciones.xlsx', index = False)





#indx = d.find(",")
#intro = d[indx+1:]
print(intro)




L  = []
x = 1
while x < 929:
    s = df.iloc[x,1]

    indx = s.find(",")
    intro = s[indx+1:]


    L.append(intro)
    x += 1
df = pd.DataFrame(L, columns=['string_values'])
print (df)
df.to_excel(r'C:\Users\usuario\Desktop\eleamdirecciones.xlsx', index = False)
# Out:
#  Calle MAGALLANES 1766, Arica, Chile
#                                          string_values
# 0            Calle 18 DE SEPTIEMBRE 1979, Arica, Chile
# 1            Calle GUILLERMO SANCHEZ 641, Arica, Chile
# 2               Calle GERMAN RIESCO 2016, Arica, Chile
# 3                       Calle REÑACA 391, Arica, Chile
# 4     Calle RAMON CARNICER PONIENTE 3186, Arica, Chile
# ..                                                 ...
# 923         Calle MAGALLANES  421, Punta Arenas, Chile
# 924        Calle 21 DE MAYO  2442, Punta Arenas, Chile
# 925                  Calle YUNGAY  488, Natales, Chile
# 926          Calle LOS PINARES 22, Punta Arenas, Chile
# 927    Calle Teniente Serrano 311, Punta Arenas, Chile
#
# [928 rows x 1 columns]
